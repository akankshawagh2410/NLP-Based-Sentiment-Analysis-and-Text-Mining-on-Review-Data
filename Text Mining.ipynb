# %%
import pandas as pd
import nltk
import csv
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import opinion_lexicon

# %%
def parse(input_path, index1, index2):
    # Load the CSV file
    df = pd.read_csv(input_path)
    # Positive and negative words (you can expand this list)
    pos_words = loadLexicon('positive-words.txt')
    neg_words = loadLexicon('negative-words.txt')
    
    fin=open(input_path,encoding='utf8')

    reader=csv.reader(fin)
     # Define a list to store nouns with opposite opinions
    opposite_opinions = []

    # Function to determine the opinion on a noun
    def get_opinion(sentence, noun, pos_words, neg_words):
        tokens = word_tokenize(sentence)
        p_count, n_count = 0, 0

        for token in tokens:
            if token in pos_words:
                p_count += 1
            elif token in neg_words:
                n_count += 1

        if p_count > n_count:
            return 'positive'
        elif p_count < n_count:
            return 'negative'
        else:
            return 'neutral'

    

    # Tokenize and process the reviews
    for review_index in [index1, index2]:
        review = df.iloc[0,1]
        sentences = sent_tokenize(review)
        for sentence in sentences:
            sentence = sentence.lower()  # Convert to lowercase for matching
            for word in pos_words + neg_words:
                if word in sentence:
                    opinion = get_opinion(sentence, word, pos_words, neg_words)
                    if opinion == 'positive':
                        pos_words.append(word)
                    elif opinion == 'negative':
                        neg_words.append(word)

    # Check for nouns with opposite opinions
    for noun in pos_words:
        if noun in neg_words:
            opposite_opinions.append(noun)

    return opposite_opinions

# %%
result = parse('amazonreviews.csv',0,1)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 result = parse('amazonreviews.csv',0,1)
#       2 print(result)
#
# Cell In[42], line 37, in parse(input_path, index1, index2)
#      35 for review_index in [index1, index2]:
#      36     review = df.iloc[0,1]
# ---> 37     sentences = sent_tokenize(review)
#      38     for sentence in sentences:
#      39         sentence = sentence.lower()  # Convert to lowercase for matching
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
#     106 tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107 return tokenizer.tokenize(text)
#
# ...
